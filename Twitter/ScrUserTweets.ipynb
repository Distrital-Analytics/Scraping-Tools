# %%
from twitterscraper import query_tweets_from_user
import datetime as dt
import pandas as pd

# %%
limit=100
user='petrogustavo'
tw=query_tweets_from_user(user,limit=limit)
# Out:
# INFO: Scraping tweets from https://twitter.com/petrogustavo
# INFO: Using proxy 125.27.251.82:50574
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/petrogustavo/timeline/tweets?include_available_features=1&include_entities=1&max_position=1220132006056558593&reset_error_state=false
# INFO: Using proxy 203.128.79.18:43227
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/petrogustavo/timeline/tweets?include_available_features=1&include_entities=1&max_position=1220094018387959812&reset_error_state=false
# INFO: Using proxy 103.88.221.105:35411
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/petrogustavo/timeline/tweets?include_available_features=1&include_entities=1&max_position=1219795856582414336&reset_error_state=false
# INFO: Using proxy 202.1.197.227:80
# ...

# %%
df=pd.DataFrame(t.__dict__ for t in tw)

# %%
df.head(10)
# Out:
#       screen_name               username   user_id             tweet_id  \
# 0    petrogustavo          Gustavo Petro  49849732  1220172623474319363
# 1    petrogustavo          Gustavo Petro  49849732  1220169961915764738
# 2    petrogustavo          Gustavo Petro  49849732  1220169550718783491
# 3  GustavoBolivar        Gustavo Bolívar  50981729  1220014840581967872
# 4    petrogustavo          Gustavo Petro  49849732  1220161429480845312
# 5    petrogustavo          Gustavo Petro  49849732  1220165077342597121
# 6    petrogustavo          Gustavo Petro  49849732  1220161429480845312
# 7   MoisesAlvaro_  Álvaro Moisés Ninco 🌎  81629449  1220147544229122050
# 8    petrogustavo          Gustavo Petro  49849732  1220159351748550668
# 9    petrogustavo          Gustavo Petro  49849732  1220156939642003456
#
#                                     tweet_url           timestamp  \
# 0    /petrogustavo/status/1220172623474319363 2020-01-23 02:33:17
# ...
