# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}

# %%
bd=dt.date(2020,1,21)
ed=dt.date(2020,1,22)
limit=100
lang= 'Spanish'
#user=petrogustavo
tw=query_tweets("paro",begindate=bd, enddate=ed, limit=limit, lang=lang)
# Out:
# INFO: queries: ['paro since:2020-01-21 until:2020-01-22']
# INFO: Got 113 tweets (113 new).

# %%
df=pd.DataFrame(t.__dict__ for t in tw)

# %%
df.head(10)
# Out:
#        screen_name               username              user_id  \
# 0      GOLDEN_2108  A PARAR PARA AVANZAR🔥           3045311845
# 1     AndraNovais1          Andréa Novais  1099886418032279553
# 2   _nenajeziorski          Jeziorski 🇪🇪♑            344978962
# 3  Mauro0269068738               Mauro 02  1209291929214685184
# 4   alejocarrillo6         @alejocarrillo  1017751170104872963
# 5  Maurici08144193            Mauro Susse  1086614662819520513
# 6    JaninCarolina                  Carol            870717980
# 7         melazary                  m e l   925532125721481216
# 8       L_eduardo8           Luis Eduardo  1004163537579794433
# 9      Juan_Felizp   Juan Felipe Restrepo             52947595
#
#               tweet_id                                    tweet_url  \
# 0  1219771651606425600      /GOLDEN_2108/status/1219771651606425600
# 1  1219771641623871488     /AndraNovais1/status/1219771641623871488
# ...
